# %%
import os
import numpy as np
from PIL import Image

def center_crop(im):
    crop_size = min(im.size)
    
    left = (im.size[0] - crop_size)//2
    top = (im.size[1]-crop_size)//2
    right = (im.size[0]+crop_size)//2
    bottom = (im.size[1]+crop_size)//2
    
    return im.crop((left, top, right, bottom))


def convert_image(src_file, dest_file):
    _, ext = os.path.splitext(src_file)
    if ext != '.ppm':
        return
    
    src_image = Image.open(src_file)
    dest_image = src_image.convert("L")
    dest_image = center_crop(dest_image).resize((32,32))
    dest_image.save(dest_file)
    
base_dir = './GTSRB/Final_Training/Images/'
target_dir = './GTSRB_IMG/'

list = os.listdir(base_dir)
for dir in list:
    dest = target_dir + dir
    
    if not os.path.exists(dest):
        os.makedirs(dest)
        
    src_dir = base_dir + dir
    file_list = os.listdir(src_dir)
        
    for file in file_list:
        src_file = src_dir + "/" + file
        dest_file = dest+ "/" + file
        convert_image(src_file, dest_file)
        
        
    print(src_dir, "완료")
# Out:
# ./GTSRB/Final_Training/Images/00000 완료
# ./GTSRB/Final_Training/Images/00001 완료
# ./GTSRB/Final_Training/Images/00002 완료
# ./GTSRB/Final_Training/Images/00003 완료
# ./GTSRB/Final_Training/Images/00004 완료
# ./GTSRB/Final_Training/Images/00005 완료
# ./GTSRB/Final_Training/Images/00006 완료
# ./GTSRB/Final_Training/Images/00007 완료
# ./GTSRB/Final_Training/Images/00008 완료
# ./GTSRB/Final_Training/Images/00009 완료
# ./GTSRB/Final_Training/Images/00010 완료
# ./GTSRB/Final_Training/Images/00011 완료
# ./GTSRB/Final_Training/Images/00012 완료
# ./GTSRB/Final_Training/Images/00013 완료
# ./GTSRB/Final_Training/Images/00014 완료
# ./GTSRB/Final_Training/Images/00015 완료
# ./GTSRB/Final_Training/Images/00016 완료
# ./GTSRB/Final_Training/Images/00017 완료
# ./GTSRB/Final_Training/Images/00018 완료
# ./GTSRB/Final_Training/Images/00019 완료
# ./GTSRB/Final_Training/Images/00020 완료
# ./GTSRB/Final_Training/Images/00021 완료
# ./GTSRB/Final_Training/Images/00022 완료
# ./GTSRB/Final_Training/Images/00023 완료
# ./GTSRB/Final_Training/Images/00024 완료
# ./GTSRB/Final_Training/Images/00025 완료
# ./GTSRB/Final_Training/Images/00026 완료
# ./GTSRB/Final_Training/Images/00027 완료
# ./GTSRB/Final_Training/Images/00028 완료
# ./GTSRB/Final_Training/Images/00029 완료
# ./GTSRB/Final_Training/Images/00030 완료
# ./GTSRB/Final_Training/Images/00031 완료
# ./GTSRB/Final_Training/Images/00032 완료
# ./GTSRB/Final_Training/Images/00033 완료
# ./GTSRB/Final_Training/Images/00034 완료
# ./GTSRB/Final_Training/Images/00035 완료
# ./GTSRB/Final_Training/Images/00036 완료
# ./GTSRB/Final_Training/Images/00037 완료
# ./GTSRB/Final_Training/Images/00038 완료
# ./GTSRB/Final_Training/Images/00039 완료
# ./GTSRB/Final_Training/Images/00040 완료
# ./GTSRB/Final_Training/Images/00041 완료
# ./GTSRB/Final_Training/Images/00042 완료
